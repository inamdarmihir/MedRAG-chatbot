# %%
# !pip install langchain faiss-cpu beautifulsoup4
# !pip install langchain_community PyPDF2 pdf2image pytesseract spacy Levenshtein
# !python -m spacy download en_core_web_sm
# Out:
# ...
# ^C
#
# Aborted.

# %%
# !python main.py --html abr.html --pdf Medical_Records.pdf
# Out:
# langchain-community not found. Installing...
# ...
# faiss-cpu not found. Installing...
# ...
# beautifulsoup4 not found. Installing...
# ...
# sentence-transformers not found. Installing...
# ...
# /opt/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# 2024-07-15 11:54:19,697 - INFO - Use pytorch device_name: cpu
# 2024-07-15 11:54:19,697 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# tokenizer_config.json: 100%|████████████████████| 363/363 [00:00<00:00, 301kB/s]
# vocab.txt: 100%|██████████████████████████████| 232k/232k [00:00<00:00, 578kB/s]
# ...
